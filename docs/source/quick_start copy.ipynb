# %% [markdown]
# # Quickstart

# %%
import re
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# import alphashape
import scanpy as sc
import pandas as pd

# %%
# import sys
# sys.path.append('/Users/koush/Projects/SpaceOracle/src')

# %%
# Human Tonsil snRNAseq from SlideTags
# https://www.nature.com/articles/s41586-023-06837-4

adata = sc.read_h5ad('/global/scratch/users/fosterangus/MetabTravLR/Data/Xenium/Primary_Dermal_Melanoma/adata.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 112551 × 5006
#     obs: 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', '_scvi_batch', '_scvi_labels', 'leiden_scVI_res_0.5', 'leiden_scVI_res_2.5', 'leiden_scVI_res_2', 'leiden_scVI_res_1.5', 'leiden_scVI_res_1', 'leiden_scVI_res_0.75', 'leiden_scVI_res_0.65', 'leiden_scVI_res_0.375', 'leiden_scVI_res_0.25', 'leiden_scVI_res_0.1', 'leiden_scVI_res_0.05', 'cd8', 'cd4', 't_cell', 'Tier1', 'Tier2', 'Tier3'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'Tier1_colors', 'Tier2_colors', 'Tier3_colors', '_scvi_manager_uuid', '_scvi_uuid', 'leiden_scVI_res_0.05', 'leiden_scVI_res_0.05_colors', 'leiden_scVI_res_0.1', 'leiden_scVI_res_0.1_colors', 'leiden_scVI_res_0.25', 'leiden_scVI_res_0.25_colors', 'leiden_scVI_res_0.375', 'leiden_scVI_res_0.375_colors', 'leiden_scVI_res_0.5', 'leiden_scVI_res_0.5_colors', 'leiden_scVI_res_0.65', 'leiden_scVI_res_0.65_colors', 'leiden_scVI_res_0.75', 'leiden_scVI_res_0.75_colors', 'leiden_scVI_res_1', 'leiden_scVI_res_1.5', 'leiden_scVI_res_1.5_colors', 'leiden_scVI_res_1_colors', 'leiden_scVI_res_2', 'leiden_scVI_res_2.5', 'leiden_scVI_res_2.5_colors', 'leiden_scVI_res_2_colors', 'neighbors', 't_cell_colors', 'umap'
#     obsm: 'X_scVI', 'X_umap', 'spatial'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs['cell_type'] = adata.obs['leiden_scVI_res_0.5']
adata.layers['raw_count'] = adata.X

# %%
from SpaceTravLR.spaceship import SpaceShip

# %%
# Note: Make sure the outdir matches the one in the launch.py file

spacetravlr = SpaceShip(
    name='Melenoma', 
    outdir='/global/scratch/users/fosterangus/MetabTravLR/Data/SpaceTravLRMelenomaTest'
)
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
spacetravlr.setup_(adata, overwrite=True, run_commot=False) # Can change overwrite to True
# Out:
# <style>
# .enlighten-fg-black {
#   color: #000000;
# }
# .enlighten-bg-cyan {
#   background-color: #00cdcd;
# }
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre><span class="enlighten-fg-black enlighten-bg-cyan">                               🚀 SpaceShip Melenoma: Initializing...                               </span></pre>
#   </div>
# </div>
# <style>
# .enlighten-fg-green {
#   color: #00cd00;
# }
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>Imputing clusterwise 100%|<span class="enlighten-fg-green">████████████████████████████████████</span>| 11/11 [02:47&lt;00:00, 0.07 clusters/s]</pre>
#   </div>
# </div>
# velocyto not found, please conda install bioconda::velocyto.py
# which: no R in (/global/home/users/fosterangus/.conda/envs/spacetravlr/bin:/global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/condabin:/global/software/rocky-8.x86_64/manual/modules/tools/code-server/code-server-4.99.3/lib/vscode/bin/remote-cli:/global/software/rocky-8.x86_64/gcc/linux-rocky8-x86_64/gcc-8.5.0/emacs-29.1-d5gecqgjml5m6y3gny5sqwqxy4mys4ex/bin:/global/software/rocky-8.x86_64/manual/modules/langs/anaconda3/2024.02-1/bin:/global/software/rocky-8.x86_64/manual/modules/tools/code-server/code-server-4.99.3/bin:/global/home/users/fosterangus/.local/bin:/global/home/users/fosterangus/bin:/usr/share/Modules/bin:/usr/local/bin:/usr/bin:/usr/local/sbin:/usr/sbin:/opt/mellanox/doca/tools:/global/home/groups/allhands/bin)
# 3 packages do not meet CellOracle requirement.
#  Your louvain version is not_found. Please install louvain
#  Your jupyter version is not_found. Please install jupyter
#  Your goatools version is not_found. Please install goatools
# 5006 genes were found in the adata. Note that Celloracle is intended to use around 1000-3000 genes, so the behavior with this number of genes may differ from what is expected.
# WARNING: adata.X seems to be already log-transformed.

# %%
assert spacetravlr.is_everything_ok()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 assert spacetravlr.is_everything_ok()
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/spaceship.py:696, in SpaceShip.is_everything_ok(self)
#     687 def is_everything_ok(self) -> bool:
#     688     """
#     689     Checks if all necessary output files and directories exist.
#     690
#    (...)    694         True if all checks pass.
#     695     """
# --> 696     assert os.path.isfile(f'{self.outdir}/input_data/_adata.h5ad'), "AnnData file not found"
#     697     _adata = sc.read_h5ad(f'{self.outdir}/input_data/_adata.h5ad')
#     698     _links = pickle.load(open(f'{self.outdir}/input_data/celloracle_links.pkl', 'rb'))
#
# AssertionError: AnnData file not found

# %%
## Run this multiple times to spawn parallel workers
spacetravlr.spawn_worker(
    account='fc_wagnerlabfca',
    partition='savio4_gpu',
    qos='a5k_gpu4_normal',
    gres='gpu:A5000:1',
    job_name='SpaceTravLR',
    cpus_per_task=4,
    lifespan=0.5,
    python_path='/global/home/users/fosterangus/.conda/envs/spacetravlr/bin/python'
)
# Out:
# Submitted batch job 35263641

# %%
spacetravlr.fit()
# Out:
# <style>
# .enlighten-fg-green {
#   color: #00cd00;
# }
# .enlighten-fg-red {
#   color: #cd0000;
# }
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>🕵️️  1 workers   0%|<span class="enlighten-fg-green">                                       </span>|    1/3333 [00:10&lt;9h 30:01, 0.10 genes/s]</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>CD48 | 1/3 | 0.0016   5%|<span class="enlighten-fg-red">█▋                            </span>|  10472/196350 [01:02&lt;18:13, 170.12 cells/s]</pre>
#   </div>
# </div>
# Deleted lock for SYCP2 after 3600 seconds
# Fitting CD48 with 741 modulators
# 	10 Transcription Factors
# 	690 Ligand-Receptor Pairs
# 	41 TranscriptionFactor-Ligand Pairs
# 	0 Extra modulators
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 spacetravlr.fit()
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/spaceship.py:612, in SpaceShip.fit(self, **kwargs)
# --> 612 def fit(self, **kwargs): return self.run_spacetravlr(**kwargs)
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/spaceship.py:69, in catch_and_retry.<locals>.wrapper.<locals>.inner(*args, **kwargs)
#      67 for i in range(0, retry):
#      68     try:
# ---> 69         return f(*args, **kwargs)
#      70     except Exception as e:
#      71         print(Status.FUBAR)
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/spaceship.py:609, in SpaceShip.run_spacetravlr(self, max_epochs, learning_rate, spatial_dim, batch_size, radius, contact_distance)
#     594 co_grn = RegulatoryFactory(links=links)
#     596 space_travlr = SpaceTravLR(
#     597     adata=adata,
#     598     max_epochs=max_epochs,
#    (...)    606     tflinks=tflinks
#     607 )
# --> 609 space_travlr.run()
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/oracles.py:489, in SpaceTravLR.run(self)
#     485     continue
#     487 self.queue.create_lock(gene)
# --> 489 estimator.fit(
#     490     num_epochs=self.max_epochs,
#     491     threshold_lambda=self.threshold_lambda,
#     492     learning_rate=self.learning_rate,
#     493     batch_size=self.batch_size,
#     494     pbar=train_bar,
#     495     skip_clusters=self.skip_clusters
#     496 )
#     498 ## filter out columns with all zeros
#     499 betadata = estimator.betadata
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/models/parallel_estimators.py:1041, in SpatialCellularProgramsEstimator.fit(self, num_epochs, threshold_lambda, learning_rate, batch_size, pbar, use_pbar, estimator, vision_model, score_threshold, l1_reg, skip_clusters, lasso_params)
#    1038 spatial_maps, inputs, targets, spatial_features = [b.to(device) for b in batch]
#    1040 optimizer.zero_grad()
# -> 1041 outputs = model(spatial_maps, inputs, spatial_features)
#    1042 loss = criterion(outputs, targets)
#    1044 loss.backward()
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/models/pixel_attention.py:262, in CellularNicheNetwork.forward(self, spatial_maps, inputs_x, spatial_features)
#     261 def forward(self, spatial_maps, inputs_x, spatial_features):
# --> 262     betas = self.get_betas(spatial_maps, spatial_features)
#     263     y_pred = self.predict_y(inputs_x, betas)
#     265     return y_pred
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/models/pixel_attention.py:245, in CellularNicheNetwork.get_betas(self, spatial_maps, spatial_features)
#     244 def get_betas(self, spatial_maps, spatial_features):
# --> 245     out = self.conv_layers(spatial_maps)
#     246     sp_out = self.spatial_features_mlp(spatial_features)
#     247     out = out+sp_out
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/modules/container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/modules/pooling.py:224, in MaxPool2d.forward(self, input)
#     222 def forward(self, input: Tensor):
#     223     """Runs the forward pass."""
# --> 224     return F.max_pool2d(
#     225         input,
#     226         self.kernel_size,
#     227         self.stride,
#     228         self.padding,
#     229         self.dilation,
#     230         ceil_mode=self.ceil_mode,
#     231         return_indices=self.return_indices,
#     232     )
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/_jit_internal.py:637, in boolean_dispatch.<locals>.fn(*args, **kwargs)
#     635     return if_true(*args, **kwargs)
#     636 else:
# --> 637     return if_false(*args, **kwargs)
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/functional.py:835, in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     833 if stride is None:
#     834     stride = torch.jit.annotate(list[int], [])
# --> 835 return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#
# KeyboardInterrupt:

# %%
spacetravlr.setup_perturbations(
    adata=adata, 
    use_float16=True
)
# Out:
# <style>
# .enlighten-fg-black {
#   color: #000000;
# }
# .enlighten-bg-green {
#   background-color: #00cd00;
# }
# .enlighten-bg-salmon {
#   background-color: #fa8072;
# }
# .enlighten-bg-cyan {
#   background-color: #00cdcd;
# }
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre><span class="enlighten-fg-black enlighten-bg-green">                               FOXO1 -&gt; 0 - 4/4 - Completed in 18.68s                               </span></pre>
#   </div>
# </div>
# <style>
# .enlighten-fg-lightblue {
#   color: #add8e6;
# }
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>Reading betadata files 100%|<span class="enlighten-fg-lightblue">██████████████████████████████████</span>| 10/10 [00:00&lt;00:00, 49.11 parquet/s]</pre>
#   </div>
# </div>

# %%
spacetravlr.perturb(
    target='FOXO1',
    propagation=4,
    gene_expr=0,
)

# %%
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version PyTorch was built with:", torch.version.cuda)
print("GPU name:", torch.cuda.get_device_name(0))
print("GPU compute capability:", torch.cuda.get_device_capability(0))
print("Supported architectures:", torch.cuda.get_arch_list())
# Out:
# PyTorch version: 2.12.0+cu130
# CUDA available: True
# CUDA version PyTorch was built with: 13.0
# GPU name: NVIDIA GeForce GTX 1080 Ti
# GPU compute capability: (6, 1)
# Supported architectures: ['sm_75', 'sm_80', 'sm_86', 'sm_90', 'sm_100', 'sm_120']
