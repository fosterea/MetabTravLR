# %% [markdown]
# # Quickstart

# %%
import re
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# import alphashape
import scanpy as sc
import pandas as pd

# %%
# import sys
# sys.path.append('/Users/koush/Projects/SpaceOracle/src')

# %%
# Human Tonsil snRNAseq from SlideTags
# https://www.nature.com/articles/s41586-023-06837-4

adata = sc.read_h5ad('/global/scratch/users/fosterangus/MetabTravLR/Data/Xenium/Primary_Dermal_Melanoma/adata.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 112551 × 5006
#     obs: 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', '_scvi_batch', '_scvi_labels', 'leiden_scVI_res_0.5', 'leiden_scVI_res_2.5', 'leiden_scVI_res_2', 'leiden_scVI_res_1.5', 'leiden_scVI_res_1', 'leiden_scVI_res_0.75', 'leiden_scVI_res_0.65', 'leiden_scVI_res_0.375', 'leiden_scVI_res_0.25', 'leiden_scVI_res_0.1', 'leiden_scVI_res_0.05', 'cd8', 'cd4', 't_cell', 'Tier1', 'Tier2', 'Tier3', 'Cytotoxic_CD8_score', 'Exhausted_CD8_score', 'Treg_score', 'sub_cluster_5_res_1', 'sub_cluster_5_res_0.75', 'sub_cluster_5_res_0.5', 'sub_cluster_5_res_0.37', 'sub_cluster_5_res_0.25', 'sub_cluster_5_res_0.15', 'sub_cluster_5_res_0.1', 'sub_cluster_5_res_0.05', 'sub_cluster_2_res_1', 'sub_cluster_2_res_0.75', 'sub_cluster_2_res_0.5', 'sub_cluster_2_res_0.37', 'sub_cluster_2_res_0.25', 'sub_cluster_2_res_0.15', 'sub_cluster_2_res_0.1', 'sub_cluster_2_res_0.05'
#     var: 'gene_ids', 'feature_types', 'genome'
#     uns: 'Tier1_colors', 'Tier2_colors', 'Tier3_colors', '_scvi_manager_uuid', '_scvi_uuid', 'cd4_colors', 'cd8_colors', 'leiden_scVI_res_0.05', 'leiden_scVI_res_0.05_colors', 'leiden_scVI_res_0.1', 'leiden_scVI_res_0.1_colors', 'leiden_scVI_res_0.25', 'leiden_scVI_res_0.25_colors', 'leiden_scVI_res_0.375', 'leiden_scVI_res_0.375_colors', 'leiden_scVI_res_0.5', 'leiden_scVI_res_0.5_colors', 'leiden_scVI_res_0.65', 'leiden_scVI_res_0.65_colors', 'leiden_scVI_res_0.75', 'leiden_scVI_res_0.75_colors', 'leiden_scVI_res_1', 'leiden_scVI_res_1.5', 'leiden_scVI_res_1.5_colors', 'leiden_scVI_res_1_colors', 'leiden_scVI_res_2', 'leiden_scVI_res_2.5', 'leiden_scVI_res_2.5_colors', 'leiden_scVI_res_2_colors', 'log1p', 'neighbors', 'rank_genes_groups', 'sub_cluster_2_res_0.05_colors', 'sub_cluster_2_res_0.15_colors', 'sub_cluster_2_res_0.1_colors', 'sub_cluster_2_res_0.25_colors', 'sub_cluster_2_res_0.37_colors', 'sub_cluster_2_res_0.5_colors', 'sub_cluster_2_res_0.75_colors', 'sub_cluster_2_res_1_colors', 'sub_cluster_5_res_0.05_colors', 'sub_cluster_5_res_0.15_colors', 'sub_cluster_5_res_0.1_colors', 'sub_cluster_5_res_0.25_colors', 'sub_cluster_5_res_0.37_colors', 'sub_cluster_5_res_0.5_colors', 'sub_cluster_5_res_0.75_colors', 'sub_cluster_5_res_1_colors', 't_cell_colors', 'umap'
#     obsm: 'X_scVI', 'X_umap', 'spatial'
#     layers: 'counts', 'log_norm'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs['cell_type'] = adata.obs['leiden_scVI_res_0.5']
adata.layers['raw_count'] = adata.X

# %%
from SpaceTravLR.spaceship import SpaceShip

# %%
# Note: Make sure the outdir matches the one in the launch.py file

spacetravlr = SpaceShip(
    name='Melenoma', 
    outdir='/global/scratch/users/fosterangus/MetabTravLR/Data/SpaceTravLRMelenomaTest',
    genes=['CD4', 'CD3E', 'FOXP3', 'IL2RA', 'CTLA4', 'IL10', 'TGFB1', 'ENTPD1']
)

# %%
spacetravlr.setup_(adata, overwrite=False, run_commot=False) # Can change overwrite to True
# Out:
# Warning: output directory already exists. Will not overwrite.

# %%
assert spacetravlr.is_everything_ok()
# Out:
# We're going on a trip in our favorite rocket ship 🚀️

# %%
spacetravlr.focus_genes = ['CD4', 'CD3E', 'FOXP3', 'IL2RA', 'CTLA4', 'IL10', 'TGFB1', 'ENTPD1']

# %%
## Run this multiple times to spawn parallel workers
spacetravlr.spawn_worker(
    account='fc_wagnerlabfca',
    partition='savio4_gpu',
    qos='a5k_gpu4_normal',
    gres='gpu:A5000:1',
    job_name='SpaceTravLR',
    cpus_per_task=4,
    lifespan=0.5,
    python_path='/global/home/users/fosterangus/.conda/envs/spacetravlr/bin/python'
)
# Out:
# Submitted batch job 35263641

# %%
spacetravlr.fit()
# Out:
# <style>
# .enlighten-fg-green {
#   color: #00cd00;
# }
# .enlighten-fg-red {
#   color: #cd0000;
# }
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>🕵️️  2 workers  12%|<span class="enlighten-fg-green">██████                                          </span>| 1/8 [00:19&lt;02:16, 0.05 genes/s]</pre>
#   </div>
#   <div class="enlighten-bar">
#     <pre>IL10 | 11/11 | 0.0000 100%|<span class="enlighten-fg-red">████████████████████</span>| 16882650/16882650 [1h 39:12&lt;00:00, 2836.68 cells/s]</pre>
#   </div>
# </div>
# Fitting IL10 with 1121 modulators
# 	85 Transcription Factors
# 	638 Ligand-Receptor Pairs
# 	398 TranscriptionFactor-Ligand Pairs
# 	0 Extra modulators
# 0: x.xxxx | 0.1629
# 1: 0.3751 | 0.3325
# 2: 0.2782 | 0.2770
# 3: 0.7734 | 0.7550
# 4: 0.3997 | 0.3975
# 5: 0.5711 | 0.5258
# 6: 0.3007 | 0.2992
# 7: 0.9172 | 0.9017
# 8: 0.3902 | 0.3898
# 9: 0.2501 | 0.2432
# 10: 0.4730 | 0.4684
# Status.FUBAR
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 spacetravlr.fit()
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/spaceship.py:647, in SpaceShip.fit(self, **kwargs)
# --> 647 def fit(self, **kwargs): return self.run_spacetravlr(**kwargs)
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/spaceship.py:72, in catch_and_retry.<locals>.wrapper.<locals>.inner(*args, **kwargs)
#      70 except Exception as e:
#      71     print(Status.FUBAR)
# ---> 72     raise e
#      73     time.sleep(i+1)
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/spaceship.py:69, in catch_and_retry.<locals>.wrapper.<locals>.inner(*args, **kwargs)
#      67 for i in range(0, retry):
#      68     try:
# ---> 69         return f(*args, **kwargs)
#      70     except Exception as e:
#      71         print(Status.FUBAR)
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/spaceship.py:644, in SpaceShip.run_spacetravlr(self, max_epochs, learning_rate, spatial_dim, batch_size, radius, contact_distance)
#     628 co_grn = RegulatoryFactory(links=links)
#     630 space_travlr = SpaceTravLR(
#     631     adata=adata,
#     632     max_epochs=max_epochs,
#    (...)    641     genes=self.focus_genes
#     642 )
# --> 644 space_travlr.run()
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/oracles.py:527, in SpaceTravLR.run(self)
#     517 estimator.fit(
#     518     num_epochs=self.max_epochs,
#     519     threshold_lambda=self.threshold_lambda,
#    (...)    523     skip_clusters=self.skip_clusters
#     524 )
#     526 ## filter out columns with all zeros
# --> 527 betadata = estimator.betadata
#     528 if betadata.shape[1] > 1:
#     529     betadata.loc[:, (betadata != 0).any(axis=0)].to_parquet(
#     530         f'{self.save_dir}/{gene}_betadata.parquet')
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/models/parallel_estimators.py:1018, in SpatialCellularProgramsEstimator.betadata(self)
#    1016 @property
#    1017 def betadata(self): ##backward compatibility
# -> 1018     return self.get_betas()
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/utils/_contextlib.py:124, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     120 @functools.wraps(func)
#     121 def decorate_context(*args, **kwargs):
#     122     # pyrefly: ignore [bad-context-manager]
#     123     with ctx_factory():
# --> 124         return func(*args, **kwargs)
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/models/parallel_estimators.py:1002, in SpatialCellularProgramsEstimator.get_betas(self)
#     998         cluster_sp_maps = torch.from_numpy(
#     999             self.sp_maps[mask][:, cluster_target:cluster_target+1, :, :]).float()
#    1000         spf = torch.from_numpy(self.spatial_features.values[mask]).float()
# -> 1002         b = self.models[cluster_target].get_betas(
#    1003             cluster_sp_maps.to(self.device),
#    1004             spf.to(self.device)
#    1005         ).cpu().numpy()
#    1007     betas.extend(b)
#    1010 return pd.DataFrame(
#    1011     betas,
#    1012     index=index_tracker,
#    1013     columns=['beta0']+['beta_'+i for i in self.modulators]
#    1014 ).reindex(self.adata.obs.index)
#
# File ~/Projects/MetabTravLR/SpaceTravLR/src/SpaceTravLR/models/pixel_attention.py:245, in CellularNicheNetwork.get_betas(self, spatial_maps, spatial_features)
#     244 def get_betas(self, spatial_maps, spatial_features):
# --> 245     out = self.conv_layers(spatial_maps)
#     246     sp_out = self.spatial_features_mlp(spatial_features)
#     247     out = out+sp_out
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/modules/container.py:253, in Sequential.forward(self, input)
#     249 """
#     250 Runs the forward pass.
#     251 """
#     252 for module in self:
# --> 253     input = module(input)
#     254 return input
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/modules/module.py:1778, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1776     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1777 else:
# -> 1778     return self._call_impl(*args, **kwargs)
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/modules/module.py:1789, in Module._call_impl(self, *args, **kwargs)
#    1784 # If we don't have any hooks, we want to skip the rest of the logic in
#    1785 # this function, and just call forward.
#    1786 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1787         or _global_backward_pre_hooks or _global_backward_hooks
#    1788         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1789     return forward_call(*args, **kwargs)
#    1791 result = None
#    1792 called_always_called_hooks = set()
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/modules/batchnorm.py:210, in _BatchNorm.forward(self, input)
#     203     bn_training = (self.running_mean is None) and (self.running_var is None)
#     205 r"""
#     206 Buffers are only updated if they are to be tracked and we are in training mode. Thus they only need to be
#     207 passed when the update should occur (i.e. in training mode when they are tracked), or when buffer stats are
#     208 used for normalization (i.e. in eval mode when buffers are not None).
#     209 """
# --> 210 return F.batch_norm(
#     211     input,
#     212     # If buffers are not to be tracked, ensure that they won't be updated
#     213     (
#     214         self.running_mean
#     215         if not self.training or self.track_running_stats
#     216         else None
#     217     ),
#     218     self.running_var if not self.training or self.track_running_stats else None,
#     219     self.weight,
#     220     self.bias,
#     221     bn_training,
#     222     exponential_average_factor,
#     223     self.eps,
#     224 )
#
# File ~/.conda/envs/spacetravlr/lib/python3.12/site-packages/torch/nn/functional.py:2850, in batch_norm(input, running_mean, running_var, weight, bias, training, momentum, eps)
#    2847 elif eps < 0.0:
#    2848     raise ValueError(f"batch_norm eps must be non-negative, but got {eps}")
# -> 2850 return torch.batch_norm(
#    2851     input,
#    2852     weight,
#    2853     bias,
#    2854     running_mean,
#    2855     running_var,
#    2856     training,
#    2857     momentum,
#    2858     eps,
#    2859     torch.backends.cudnn.enabled,
#    2860 )
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 9.28 GiB. GPU 0 has a total capacity of 10.57 GiB of which 205.06 MiB is free. Including non-PyTorch memory, this process has 10.36 GiB memory in use. Of the allocated memory 9.88 GiB is allocated by PyTorch, and 287.34 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://docs.pytorch.org/docs/stable/notes/cuda.html#optimizing-memory-usage-with-pytorch-cuda-alloc-conf)

# %%
spacetravlr.setup_perturbations(
    adata=adata, 
    use_float16=True
)
# Out:
# <style>
# .enlighten-fg-black {
#   color: #000000;
# }
# .enlighten-bg-green {
#   background-color: #00cd00;
# }
# .enlighten-bg-salmon {
#   background-color: #fa8072;
# }
# .enlighten-bg-cyan {
#   background-color: #00cdcd;
# }
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre><span class="enlighten-fg-black enlighten-bg-green">                               FOXO1 -&gt; 0 - 4/4 - Completed in 18.68s                               </span></pre>
#   </div>
# </div>
# <style>
# .enlighten-fg-lightblue {
#   color: #add8e6;
# }
# </style>
# <div class="enlighten">
#   <div class="enlighten-bar">
#     <pre>Reading betadata files 100%|<span class="enlighten-fg-lightblue">██████████████████████████████████</span>| 10/10 [00:00&lt;00:00, 49.11 parquet/s]</pre>
#   </div>
# </div>

# %%
spacetravlr.perturb(
    target='FOXO1',
    propagation=4,
    gene_expr=0,
)

# %%
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version PyTorch was built with:", torch.version.cuda)
print("GPU name:", torch.cuda.get_device_name(0))
print("GPU compute capability:", torch.cuda.get_device_capability(0))
print("Supported architectures:", torch.cuda.get_arch_list())
# Out:
# PyTorch version: 2.12.0+cu130
# CUDA available: True
# CUDA version PyTorch was built with: 13.0
# GPU name: NVIDIA GeForce GTX 1080 Ti
# GPU compute capability: (6, 1)
# Supported architectures: ['sm_75', 'sm_80', 'sm_86', 'sm_90', 'sm_100', 'sm_120']
